# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r'C:\Users\acer\auto-plus.csv')

# %%
df.dtypes
# Out:
# Unnamed: 0                int64
# Unnamed: 0.1              int64
# lien                     object
#  Marque                  object
#  Modèle                  object
#  Mise en circulation     object
#  Energie                 object
#  Boite vitesse           object
#  kilométrage:            object
#  Puissance fiscal:       object
#  Etat du véhicule        object
# date annonce             object
# Prix                    float64
# dtype: object

# %%
df=df.drop(['Unnamed: 0', 'Unnamed: 0.1'], axis=1)

# %%
for i in df.index:
    if(df.loc[i,'Prix']<1000):
        df.loc[i,'Prix']=df.loc[i,'Prix']*1000

# %%
df.index
# Out:
# RangeIndex(start=0, stop=4666, step=1)

# %%
for i in df.index :
    print(df.loc[i,'Prix'])
# Out:
# 69000.0
# 41500.0
# 22500.0
# 38500.0
# 25900.0
# 38000.0
# 58000.0
# 56900.0
# 23000.0
# 27900.0
# 29500.0
# 38900.0
# 50000.0
# 95000.0
# 69000.0
# 29000.0
# 35000.0
# 38900.0
# 52500.0
# 55000.0
# 34900.0
# nan
# 30500.0
# 34500.0
# 129000.0
# 127000.0
# 43000.0
# 67000.0
# 46500.0
# 34500.0
# 45500.0
# 62000.0
# 43000.0
# 54000.0
# 109000.0
# 42000.0
# 25500.0
# 43500.0
# 27900.0
# 69900.0
# 28900.0
# 49500.0
# 63000.0
# 34000.0
# 26000.0
# 46000.0
# 45000.0
# nan
# nan
# nan
# 46500.0
# 25500.0
# 28000.0
# 38500.0
# 27500.0
# 25500.0
# 59500.0
# 39500.0
# 74000.0
# 36900.0
# 46000.0
# 59500.0
# 10000.0
# 49500.0
# 38000.0
# 36000.0
# 65000.0
# 25500.0
# 34500.0
# 32500.0
# 122000.0
# 64500.0
# 95500.0
# 49500.0
# 66000.0
# 39900.0
# 23500.0
# 15900.0
# 29000.0
# 23500.0
# 44000.0
# 31000.0
# 52000.0
# 42000.0
# 37500.0
# 35500.0
# 31500.0
# 47000.0
# 36000.0
# 43900.0
# 26000.0
# 36000.0
# 27900.0
# 25500.0
# 19500.0
# 78000.0
# 25500.0
# 52000.0
# 28500.0
# 31500.0
# 26500.0
# ...

# %%
df.rename(columns={'lien':'lien','Marque':'Marque','Modèle':'Modèle','Mise en circulation':'Année','Energie':'Carburant','Boite vitesse':'Boite vitesse','kilométrage:':'Kilométrage','Puissance fiscal:':'Puissance fiscale','Etat du véhicule':'Etat du véhicule','date annonce':'date annonce','Prix':'Prix'})
# Out:
#                                                    lien      Marque  \
# 0     https://www.auto-plus.tn/voitures-d-occasion/a...  Volkswagen
# 1     https://www.auto-plus.tn/voitures-d-occasion/a...  Volkswagen
# 2     https://www.auto-plus.tn/voitures-d-occasion/a...       Smart
# 3     https://www.auto-plus.tn/voitures-d-occasion/a...     Peugeot
# 4     https://www.auto-plus.tn/voitures-d-occasion/a...    Mercedes
# 5     https://www.auto-plus.tn/voitures-d-occasion/a...      Nissan
# 6     https://www.auto-plus.tn/voitures-d-occasion/a...     Renault
# 7     https://www.auto-plus.tn/voitures-d-occasion/a...  Volkswagen
# 8     https://www.auto-plus.tn/voitures-d-occasion/a...         Kia
# 9     https://www.auto-plus.tn/voitures-d-occasion/a...        Fiat
# 10    https://www.auto-plus.tn/voitures-d-occasion/a...     Renault
# 11    https://www.auto-plus.tn/voitures-d-occasion/a...  Volkswagen
# 12    https://www.auto-plus.tn/voitures-d-occasion/a...       Mazda
# ...

# %%
df
# Out:
#                                                    lien      Marque  \
# 0     https://www.auto-plus.tn/voitures-d-occasion/a...  Volkswagen
# 1     https://www.auto-plus.tn/voitures-d-occasion/a...  Volkswagen
# 2     https://www.auto-plus.tn/voitures-d-occasion/a...       Smart
# 3     https://www.auto-plus.tn/voitures-d-occasion/a...     Peugeot
# 4     https://www.auto-plus.tn/voitures-d-occasion/a...    Mercedes
# 5     https://www.auto-plus.tn/voitures-d-occasion/a...      Nissan
# 6     https://www.auto-plus.tn/voitures-d-occasion/a...     Renault
# 7     https://www.auto-plus.tn/voitures-d-occasion/a...  Volkswagen
# 8     https://www.auto-plus.tn/voitures-d-occasion/a...         Kia
# 9     https://www.auto-plus.tn/voitures-d-occasion/a...        Fiat
# 10    https://www.auto-plus.tn/voitures-d-occasion/a...     Renault
# 11    https://www.auto-plus.tn/voitures-d-occasion/a...  Volkswagen
# 12    https://www.auto-plus.tn/voitures-d-occasion/a...       Mazda
# ...
